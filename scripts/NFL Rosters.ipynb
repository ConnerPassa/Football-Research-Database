# %% [markdown]
# # Script For Downloading Rosters

# %%
import nfl_data_py as nfl
import pandas as pd

# %%
rosters = nfl.import_seasonal_rosters(list(range(2010, 2025)))

# %%
rosters.head()
# Out:
#    season team position depth_chart_position jersey_number status  \
# 0    2010  PIT        T                 None            71    ACT
# 1    2010  PHI        K                 None             2    ACT
# 2    2010   SD       LS                 None            64    CUT
# 3    2010  BLT      ILB                 None            51    ACT
# 4    2010  DEN       CB                 None            24    ACT
#
#           player_name first_name   last_name birth_date  ...  \
# 0       Flozell Adams    Flozell       Adams 1975-05-18  ...
# 1         David Akers      David       Akers 1974-12-09  ...
# 2      Ethan Albright   Lawrence    Albright 1971-05-01  ...
# 3  Brendon Ayanbadejo    Brendon  Ayanbadejo 1976-09-06  ...
# 4        Champ Bailey     Roland      Bailey 1978-06-22  ...
#
#    status_description_abbr  football_name     esb_id gsis_it_id  \
# 0                      A01        Flozell  ADA280969       None
# 1                      A01          David  AKE551610       None
# ...

# %%
rosters.to_csv("rosters_2010_2025.csv", index = False)
